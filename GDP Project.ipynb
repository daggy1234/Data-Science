# %% [markdown]
# # A PROJECT TO ANALYSE ECONOMIC DATA

# %% [markdown]
# **using python by Arnav Jindal**

# %% [markdown]
# ```We import the library and initailise the CSV data using the read_csv builtin. The initialisation uses sensitive API keys so it has been hidden.
# Please enjoy this project and DO NOT make unauthorised changes```

# %%
import pandas as pd

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### `GDP DATA TABLE`
#
# **DATE**: *Refers to the year*
#
# **A191RO1Q156NBEA**:  *Refers to the GDP % change*

# %%
gdp = pd.read_csv(body)
gdp.head()
# Out:
#          DATE  A191RO1Q156NBEA
# 0  1948-01-01              2.6
# 1  1948-04-01              4.6
# 2  1948-07-01              5.4
# 3  1948-10-01              3.9
# 4  1949-01-01              0.9

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### `The Data below has multiple iterations`
#
#
# **Date**: *Refers to the year*
#
# **UNRATE**: *Unemployment rate in %*

# %%
unemp = pd.read_csv(body)
unemp.head()
# Out:
#          DATE    UNRATE
# 0  1948-01-01  3.733333
# 1  1948-04-01  3.666667
# 2  1948-07-01  3.766667
# 3  1948-10-01  3.833333
# 4  1949-01-01  4.666667

# %% [markdown]
# `We now create a new dataframe to show where unemployment was greater than 8.5%`

# %%
highunemp = unemp[unemp['UNRATE']>8.5]
highunemp
# Out:
#            DATE  UNRATE
# 326  1975-03-01     8.6
# 327  1975-04-01     8.8
# 328  1975-05-01     9.0
# 329  1975-06-01     8.8
# 330  1975-07-01     8.6
# 408  1982-01-01     8.6
# 409  1982-02-01     8.9
# 410  1982-03-01     9.0
# 411  1982-04-01     9.3
# 412  1982-05-01     9.4
# 413  1982-06-01     9.6
# 414  1982-07-01     9.8
# 415  1982-08-01     9.8
# 416  1982-09-01    10.1
# 417  1982-10-01    10.4
# 418  1982-11-01    10.8
# 419  1982-12-01    10.8
# 420  1983-01-01    10.4
# 421  1983-02-01    10.4
# 422  1983-03-01    10.3
# 423  1983-04-01    10.2
# 424  1983-05-01    10.1
# 425  1983-06-01    10.1
# 426  1983-07-01     9.4
# 427  1983-08-01     9.5
# 428  1983-09-01     9.2
# 429  1983-10-01     8.8
# 734  2009-03-01     8.7
# 735  2009-04-01     9.0
# 736  2009-05-01     9.4
# 737  2009-06-01     9.5
# 738  2009-07-01     9.5
# 739  2009-08-01     9.6
# 740  2009-09-01     9.8
# 741  2009-10-01    10.0
# 742  2009-11-01     9.9
# 743  2009-12-01     9.9
# ...

# %% [markdown]
# `I used madplotlib to plot the dataframe and make a dashboard`

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
def make_dashboard():
    ax = plt.gca()
    gdp.plot(kind='line',x='DATE',y='A191RO1Q156NBEA',ax=ax)
    unemp.plot(kind='line',x='DATE',y='UNRATE',ax=ax)
    plt.show()

# %% [markdown]
# `I now call the function`

# %%
make_dashboard()

# %% [markdown]
# ~~thanks for viewing this~~

# %% [markdown]
# Thanking reliable sources for data!
#
#
# [source](https://fred.stlouisfed.org)
